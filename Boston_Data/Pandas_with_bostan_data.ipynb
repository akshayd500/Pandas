# %% [markdown]
# # Pandas with bostan data

# %%
import pandas as pd
import numpy as np

# %%
h = np.arange(1,101)

h.shape=10,10
print(type(h))

h.reshape(10,10)
print(type(h))
# Out:
# <type 'numpy.ndarray'>
# <type 'numpy.ndarray'>

# %%
data = pd.read_csv("Boston.csv")

# %%
data.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
'''#last 5 values
data.tail()
'''
data.tail(10)
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm   age     dis  rad  \
# 496         497  0.28960  0.0   9.69     0  0.585  5.390  72.9  2.7986    6
# 497         498  0.26838  0.0   9.69     0  0.585  5.794  70.6  2.8927    6
# 498         499  0.23912  0.0   9.69     0  0.585  6.019  65.3  2.4091    6
# 499         500  0.17783  0.0   9.69     0  0.585  5.569  73.5  2.3999    6
# 500         501  0.22438  0.0   9.69     0  0.585  6.027  79.7  2.4982    6
# 501         502  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 496  391     19.2  396.90  21.14  19.7
# 497  391     19.2  396.90  14.10  18.3
# ...

# %%
data["crim"].head()
data["crim"][8]
# Out:
# 0.21124

# %%
small_data = data[["crim","age","medv"]]
small_data
# Out:
#          crim    age  medv
# 0     0.00632   65.2  24.0
# 1     0.02731   78.9  21.6
# 2     0.02729   61.1  34.7
# 3     0.03237   45.8  33.4
# 4     0.06905   54.2  36.2
# 5     0.02985   58.7  28.7
# 6     0.08829   66.6  22.9
# 7     0.14455   96.1  27.1
# 8     0.21124  100.0  16.5
# 9     0.17004   85.9  18.9
# 10    0.22489   94.3  15.0
# 11    0.11747   82.9  18.9
# 12    0.09378   39.0  21.7
# 13    0.62976   61.8  20.4
# 14    0.63796   84.5  18.2
# 15    0.62739   56.5  19.9
# 16    1.05393   29.3  23.1
# 17    0.78420   81.7  17.5
# 18    0.80271   36.6  20.2
# 19    0.72580   69.5  18.2
# 20    1.25179   98.1  13.6
# 21    0.85204   89.2  19.6
# 22    1.23247   91.7  15.2
# 23    0.98843  100.0  14.5
# 24    0.75026   94.1  15.6
# 25    0.84054   85.7  13.9
# 26    0.67191   90.3  16.6
# 27    0.95577   88.8  14.8
# 28    0.77299   94.4  18.4
# 29    1.00245   87.3  21.0
# ..        ...    ...   ...
# 476   4.87141   93.6  16.7
# 477  15.02340   97.3  12.0
# ...

# %%
age_more_than_50 = data[ data["age"] > 50 ]
age_more_than_50
# Out:
#      Unnamed: 0      crim    zn  indus  chas    nox     rm    age     dis  \
# 0             1   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900
# 1             2   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671
# 2             3   0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671
# 4             5   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622
# 5             6   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622
# 6             7   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605
# 7             8   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505
# 8             9   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821
# 9            10   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921
# 10           11   0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467
# 11           12   0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267
# 13           14   0.62976   0.0   8.14     0  0.538  5.949   61.8  4.7075
# ...

# %%
age_more_than_50 = data[ data["age"] > 50 ][data["age"]<60]
age_more_than_50
# Out:
# /home/ubuntu/.local/lib/python2.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      Unnamed: 0      crim    zn  indus  chas     nox     rm   age     dis  \
# 4             5   0.06905   0.0   2.18     0  0.4580  7.147  54.2  6.0622
# 5             6   0.02985   0.0   2.18     0  0.4580  6.430  58.7  6.0622
# 15           16   0.62739   0.0   8.14     0  0.5380  5.834  56.5  4.4986
# 64           65   0.01951  17.5   1.38     0  0.4161  7.104  59.5  9.2229
# 78           79   0.05646   0.0  12.83     0  0.4370  6.232  53.7  5.0141
# 85           86   0.05735   0.0   4.49     0  0.4490  6.630  56.1  4.4377
# 87           88   0.07151   0.0   4.49     0  0.4490  6.121  56.8  3.7476
# 92           93   0.04203  28.0  15.04     0  0.4640  6.442  53.6  3.6659
# 95           96   0.12204   0.0   2.89     0  0.4450  6.625  57.8  3.4952
# ...

# %%
age_more_than_50 = data[ ( data["age"] > 50 ) & ( data["age"] < 60 ) ]
age_more_than_50
# Out:
#      Unnamed: 0      crim    zn  indus  chas     nox     rm   age     dis  \
# 4             5   0.06905   0.0   2.18     0  0.4580  7.147  54.2  6.0622
# 5             6   0.02985   0.0   2.18     0  0.4580  6.430  58.7  6.0622
# 15           16   0.62739   0.0   8.14     0  0.5380  5.834  56.5  4.4986
# 64           65   0.01951  17.5   1.38     0  0.4161  7.104  59.5  9.2229
# 78           79   0.05646   0.0  12.83     0  0.4370  6.232  53.7  5.0141
# 85           86   0.05735   0.0   4.49     0  0.4490  6.630  56.1  4.4377
# 87           88   0.07151   0.0   4.49     0  0.4490  6.121  56.8  3.7476
# 92           93   0.04203  28.0  15.04     0  0.4640  6.442  53.6  3.6659
# 95           96   0.12204   0.0   2.89     0  0.4450  6.625  57.8  3.4952
# 110         111   0.10793   0.0   8.56     0  0.5200  6.195  54.4  2.7778
# 179         180   0.05780   0.0   2.46     0  0.4880  6.980  58.4  2.8290
# 186         187   0.05602   0.0   2.46     0  0.4880  7.831  53.6  3.1992
# ...

# %% [markdown]
# # function iloc[]
#  to view detail data of specific person

# %%
data.iloc[60]
# Out:
# Unnamed: 0     61.00000
# crim            0.14932
# zn             25.00000
# indus           5.13000
# chas            0.00000
# nox             0.45300
# rm              5.74100
# age            66.20000
# dis             7.22540
# rad             8.00000
# tax           284.00000
# ptratio        19.70000
# black         395.11000
# lstat          13.15000
# medv           18.70000
# Name: 60, dtype: float64

# %%
data.iloc[3:6]
# Out:
#    Unnamed: 0     crim   zn  indus  chas    nox     rm   age     dis  rad  \
# 3           4  0.03237  0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905  0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# 5           6  0.02985  0.0   2.18     0  0.458  6.430  58.7  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2
# 5  222     18.7  394.12   5.21  28.7

# %%
data.loc[3:6]
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# 5           6  0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3
# 6           7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5
#
#    tax  ptratio   black  lstat  medv
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2
# 5  222     18.7  394.12   5.21  28.7
# 6  311     15.2  395.60  12.43  22.9

# %%
data.shape[0]
# Out:
# 506

# %%
data.columns
# Out:
# Index([u'Unnamed: 0', u'crim', u'zn', u'indus', u'chas', u'nox', u'rm', u'age',
#        u'dis', u'rad', u'tax', u'ptratio', u'black', u'lstat', u'medv'],
#       dtype='object')

# %%
#data.drop(["colunm_1","colunm_2"],axis=1)
data.drop('Unnamed: 0',axis = 1)
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6     0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10    0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11    0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...

# %%
age_sum=0
for i in range(data.shape[0]):
    age_sum += data.iloc[i]["age"]
avg = age_sum / data.shape[0]
print(avg)
# Out:
# 68.57490118577078

# %%
data["age"].mean()
# Out:
# 68.57490118577076

# %%
data.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677082   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
age_20_more = data [ data.age > 20 ]
age_20_less = data [ data.age < 20 ]
print("Age more than 20 : " ,age_20_more["crim"].mean())
print("Age less than 20 : " ,age_20_less.crim.mean())
# Out:
# ('Age more than 20 : ', 3.865390275423729)
# ('Age less than 20 : ', 0.11702088235294117)

# %%
avg_crim = data["crim"].mean()

# %%
avg_crim
# Out:
# 3.613523557312254

# %%
crim_above_avg = data [ data [ "crim" ] > avg_crim ]
crim_above_avg.mean()["ptratio"]
# Out:
# 20.15703124999999

# %%
crim_below_avg = data [ data.crim < avg_crim ]
crim_below_avg.mean()["ptratio"]
# Out:
# 17.879365079365062

# %%
data.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677082   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
crim_below_20_percentage = data.sort_values(by="crim")[:101]

# %%
crim_below_20_percentage.mean()["age"]
# Out:
# 42.726732673267335
